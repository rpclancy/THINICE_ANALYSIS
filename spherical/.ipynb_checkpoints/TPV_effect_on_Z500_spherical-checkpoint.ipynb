# %%
'''

This code is used to investigate the effects of TPVs on Z500 and Z500 ensemble spread


'''
# %matplotlib inline

import cartopy.crs as ccrs
import copy
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

from datetime import datetime
from netCDF4 import Dataset

#import read_ecmwf_utils as reu
#import read_TPV_utils as rtu
import spatial_utils as su
import plot_utils as pu
import spherical_plot_utils as spu
import save_utils as sau

# %%
import importlib
#importlib.reload(sau)
#importlib.reload(spu)
#importlib.reload(su)

# %% [markdown]
# ### Define class for keeping info about each analysis

# %%
class spatial_info:   
    # Forecast offset options in days
    # Select using t_ind. e.g. day_ind(0)=1, day_ind(6)=14;
    day_ind = ('1', '2', '3', '5', '7', '10', '14')
    
    def __init__(self, nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d):
        # File name from which variable will be loaded
        self.nc_file = nc_file
        # Variable name to be loaded
        self.var_name = var_name
        # Time offset (set as False if not doing a forecast)
        self.t_ind = t_ind
        # Scale anomalies by climatology standard deviation if True, else False
        self.scale = scale
        # Select which months to include
        self.months = months
        # Amplitude fraction. The upper amp_perc percentage of amplitudes is used.
        self.amp_perc = amp_perc
        # Maximum latitude. Above this variable ignored.
        self.max_lat = max_lat
        # Maximum distance (km). Beyond this radius variable ignored/
        self.max_d = max_d
        # Resolution (degrees) of grid on which final compositing is done.
        self.step_size_a = step_size_a
        # Resolution (km) of grid on which final compositing is done.
        self.step_size_d = step_size_d
        # Getting date name
        self.var_date_name = var_name + '_dates'

# %% [markdown]
# ### Effect of TPVs on Z500

# %%
#standard
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/Z500/Z500.nc'
var_name = 'Z500'
t_ind = False
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

Z500_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, Z500_grid, grid_count)

spu.pcolor_tpv_spherical(Z500_grid, step_size_d, max_d, step_size_a, var_name, scale)
spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
#scaled by stdv
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/Z500/Z500.nc'
var_name = 'Z500'
t_ind = False
scale = True
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

Z500_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, Z500_grid, grid_count)

spu.pcolor_tpv_spherical(Z500_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)

# %%
#limit max lat
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL.nc'
var_name = 'PSL'
t_ind = False
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 80
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
#limit max amplitude
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL.nc'
var_name = 'PSL'
t_ind = False
scale = False
months = (6,7,8)
amp_perc = 25
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
#high max_d
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL.nc'
var_name = 'PSL'
t_ind = False
scale = True
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 5200
step_size_d = 400
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
# Testing reading of numpy arrays
#npzfile = np.load(outfile)
#print(npzfile.files)
#npzfile['x_im']

# %% [markdown]
# ### TPV effect on PSL RMSE

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 0
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)

#
#
# OK, BUT SHOULDN'T THESE RMSE VALUES BE=0? hmmm?
#
#
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 1
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 2
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 3
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 4
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 5
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
t_ind = 6
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)
# Out:
# 17  out of 18

# %% [markdown]
# ### TPV effect on PSL stdv

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_stdv.nc'
var_name = 'PSL_stdv'
t_ind = 0
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)

#
#
# OK, BUT SHOULDN'T THESE RMSE VALUES BE=0? hmmm?
#
#
# Out:
# PSL_stdv :  (7, 20, 240, 2054)
# PSL_stdv_dates :  (3, 2054)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)
# 0 out of 2054
# 1 out of 2054
# 2 out of 2054
# 3 out of 2054
# 4 out of 2054
# 5 out of 2054
# 6 out of 2054
# 7 out of 2054
# 8 out of 2054
# 9 out of 2054
# 10 out of 2054
# 11 out of 2054
# 12 out of 2054
# 13 out of 2054
# 14 out of 2054
# 15 out of 2054
# 16 out of 2054
# 17 out of 2054
# 18 out of 2054
# 19 out of 2054
# 20 out of 2054
# 21 out of 2054
# 22 out of 2054
# 23 out of 2054
# 24 out of 2054
# 25 out of 2054
# 26 out of 2054
# 27 out of 2054
# 28 out of 2054
# 29 out of 2054
# 30 out of 2054
# 31 out of 2054
# 32 out of 2054
# 33 out of 2054
# 34 out of 2054
# 35 out of 2054
# 36 out of 2054
# 37 out of 2054
# 38 out of 2054
# 39 out of 2054
# 40 out of 2054
# 41 out of 2054
# 42 out of 2054
# 43 out of 2054
# 44 out of 2054
# 45 out of 2054
# 46 out of 2054
# 47 out of 2054
# 48 out of 2054
# 49 out of 2054
# 50 out of 2054
# 51 out of 2054
# 52 out of 2054
# 53 out of 2054
# 54 out of 2054
# 55 out of 2054
# 56 out of 2054
# 57 out of 2054
# 58 out of 2054
# 59 out of 2054
# 60 out of 2054
# 61 out of 2054
# 62 out of 2054
# 63 out of 2054
# 64 out of 2054
# 65 out of 2054
# 66 out of 2054
# 67 out of 2054
# 68 out of 2054
# 69 out of 2054
# 551 out of 2054
# 552 out of 2054
# 553 out of 2054
# 554 out of 2054
# 555 out of 2054
# 556 out of 2054
# 557 out of 2054
# 558 out of 2054
# 559 out of 2054
# 560 out of 2054
# 561 out of 2054
# 562 out of 2054
# 563 out of 2054
# 564 out of 2054
# 565 out of 2054
# 566 out of 2054
# 567 out of 2054
# 568 out of 2054
# 569 out of 2054
# 570 out of 2054
# 571 out of 2054

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_stdv.nc'
PSL_stdv_grid, grid_count, x_im, y_im = su.var_TPV_full_spatial(
            nc_file, 'PSL_stdv', 'PSL_stdv_dates', scale=False, t_ind=0)
pu.pcolor_tpv_spatial(PSL_stdv_grid, x_im, y_im, 'PSL_stdv', scale=False)
# Out:
# PSL_stdv :  (7, 20, 240, 2054)
# PSL_stdv_dates :  (3, 2054)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)
# /home/disk/sipn/rclancy/analysis/spatial_utils.py:156: RuntimeWarning: Mean of empty slice
#   var_grid[i,j] = np.nanmean(var_grid_sub)

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_stdv.nc'
var_name = 'PSL_stdv'
t_ind = 1
scale = False
months = (6,7,8)
amp_perc = 100
max_lat = 90
max_d = 1500
step_size_d = 100
step_size_a = 20
info_1 = spatial_info(nc_file, var_name, t_ind, scale, months, amp_perc, max_lat, max_d, step_size_a, step_size_d)

PSL_grid, grid_count, a_im, d_im = su.var_TPV_full_spatial(info_1)
sau.save_spherical_np(info_1, PSL_grid, grid_count)

spu.pcolor_tpv_spherical(PSL_grid, step_size_d, max_d, step_size_a, var_name, scale)
#spu.pcolor_gridcount_spherical(grid_count, step_size_d, max_d, step_size_a)

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_stdv.nc'
PSL_stdv_grid, grid_count, x_im, y_im = su.var_TPV_full_spatial(
            nc_file, 'PSL_stdv', 'PSL_stdv_dates', scale=False, t_ind=1)
pu.pcolor_tpv_spatial(PSL_stdv_grid, x_im, y_im, 'PSL_stdv', scale=False)
# Out:
# PSL_stdv :  (7, 20, 240, 2054)
# PSL_stdv_dates :  (3, 2054)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)
# /home/disk/sipn/rclancy/analysis/spatial_utils.py:156: RuntimeWarning: Mean of empty slice
#   var_grid[i,j] = np.nanmean(var_grid_sub)

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_stdv.nc'
PSL_stdv_grid, grid_count, x_im, y_im = su.var_TPV_full_spatial(
            nc_file, 'PSL_stdv', 'PSL_stdv_dates', scale=False, t_ind=2)
pu.pcolor_tpv_spatial(PSL_stdv_grid, x_im, y_im, 'PSL_stdv', scale=False)
# Out:
# PSL_stdv :  (7, 20, 240, 2054)
# PSL_stdv_dates :  (3, 2054)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)
# /home/disk/sipn/rclancy/analysis/spatial_utils.py:156: RuntimeWarning: Mean of empty slice
#   var_grid[i,j] = np.nanmean(var_grid_sub)
