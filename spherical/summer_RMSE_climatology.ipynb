# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

import read_ecmwf_utils as reu

from netCDF4 import Dataset

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/PSL/PSL_RMSE.nc'
var_name = 'PSL_RMSE'
var_date_name = 'PSL_RMSE_dates'

PSL_RMSE, var_dates =reu.read_nc_var(nc_file, var_name, var_date_name)

# Get associated dates
PSL_year, PSL_month, PSL_day = reu.get_y_mo_d(var_dates)

# Get lat/lon
latitude_ecmwf, longitude_ecmwf, latmesh_ecmwf, lonmesh_ecmwf = reu.get_ecmwf_lat_lon(nc_file)
# Out:
# PSL_RMSE :  (7, 20, 240, 2054)
# PSL_RMSE_dates :  (3, 2054)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)

# %%
fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.axes(projection=ccrs.Robinson())
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.set_aspect('auto')
ax.coastlines(linewidth=2)
plt.pcolormesh(lonmesh_ecmwf, latmesh_ecmwf, np.nanmean(PSL_RMSE[3, :, :, np.isin(PSL_month,[6,7,8])],0), transform = ccrs.PlateCarree(),cmap='jet')
plt.colorbar(fraction=0.023, pad=0.04, label = 'PSL_RMSE')
A, B = plt.gci().get_clim()
cmax=np.abs(np.array([A, B])).max()
plt.clim(cmax/2, cmax)
plt.show()

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/Z500/Z500_RMSE.nc'
var_name = 'Z500_RMSE'
var_date_name = 'Z500_RMSE_dates'

Z500_RMSE, var_dates =reu.read_nc_var(nc_file, var_name, var_date_name)

# Get associated dates
Z500_year, Z500_month, Z500_day = reu.get_y_mo_d(var_dates)

# Get lat/lon
latitude_ecmwf, longitude_ecmwf, latmesh_ecmwf, lonmesh_ecmwf = reu.get_ecmwf_lat_lon(nc_file)
# Out:
# Z500_RMSE :  (7, 20, 240, 2034)
# Z500_RMSE_dates :  (3, 2034)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)

# %%
fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.axes(projection=ccrs.Robinson())
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.set_aspect('auto')
ax.coastlines(linewidth=2)
plt.pcolormesh(lonmesh_ecmwf, latmesh_ecmwf, np.nanmean(Z500_RMSE[3, :, :, np.isin(Z500_month,[6,7,8])],0), transform = ccrs.PlateCarree(),cmap='jet')
plt.colorbar(fraction=0.023, pad=0.04, label = 'Z500_RMSE')
A, B = plt.gci().get_clim()
cmax=np.abs(np.array([A, B])).max()
plt.clim(cmax/2, cmax)
plt.show()

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/SIC/SIC_RMSE.nc'
var_name = 'SIC_RMSE'
var_date_name = 'SIC_RMSE_dates'

SIC_RMSE, var_dates =reu.read_nc_var(nc_file, var_name, var_date_name)

# Get associated dates
SIC_year, SIC_month, SIC_day = reu.get_y_mo_d(var_dates)

# Get lat/lon
latitude_ecmwf, longitude_ecmwf, latmesh_ecmwf, lonmesh_ecmwf = reu.get_ecmwf_lat_lon(nc_file)
# Out:
# SIC_RMSE :  (7, 20, 240, 2096)
# SIC_RMSE_dates :  (3, 2096)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)

# %%
fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.axes(projection=ccrs.Robinson())
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.set_aspect('auto')
ax.coastlines(linewidth=2)
plt.pcolormesh(lonmesh_ecmwf, latmesh_ecmwf, np.nanmean(SIC_RMSE[3, :, :, np.isin(SIC_month,[6,7,8])],0), transform = ccrs.PlateCarree(),cmap='jet')
plt.colorbar(fraction=0.023, pad=0.04, label = 'SIC_RMSE')
A, B = plt.gci().get_clim()
cmax=np.abs(np.array([A, B])).max()
plt.clim(0, cmax)
plt.show()
# Out:
# /home/disk/sipn/nicway/anaconda3/envs/esio/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/U/U_RMSE.nc'
var_name = 'U_RMSE'
var_date_name = 'U_RMSE_dates'

U_RMSE, var_dates =reu.read_nc_var(nc_file, var_name, var_date_name)

# Get associated dates
U_year, U_month, U_day = reu.get_y_mo_d(var_dates)

# Get lat/lon
latitude_ecmwf, longitude_ecmwf, latmesh_ecmwf, lonmesh_ecmwf = reu.get_ecmwf_lat_lon(nc_file)
# Out:
# U_RMSE :  (7, 20, 240, 2045)
# U_RMSE_dates :  (3, 2045)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)

# %%
fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.axes(projection=ccrs.Robinson())
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.set_aspect('auto')
ax.coastlines(linewidth=2)
plt.pcolormesh(lonmesh_ecmwf, latmesh_ecmwf, np.nanmean(U_RMSE[3, :, :, np.isin(U_month,[6,7,8])],0), transform = ccrs.PlateCarree(),cmap='jet')
plt.colorbar(fraction=0.023, pad=0.04, label = 'U_RMSE')
A, B = plt.gci().get_clim()
cmax=np.abs(np.array([A, B])).max()
plt.clim(0, cmax)
plt.show()

# %%
nc_file = '/home/disk/sipn/rclancy/ecmwf/pf/predictability/V/V_RMSE.nc'
var_name = 'V_RMSE'
var_date_name = 'V_RMSE_dates'

V_RMSE, var_dates =reu.read_nc_var(nc_file, var_name, var_date_name)

# Get associated dates
V_year, V_month, V_day = reu.get_y_mo_d(var_dates)

# Get lat/lon
latitude_ecmwf, longitude_ecmwf, latmesh_ecmwf, lonmesh_ecmwf = reu.get_ecmwf_lat_lon(nc_file)
# Out:
# V_RMSE :  (7, 20, 240, 2117)
# V_RMSE_dates :  (3, 2117)
# latitude_ecmwf:  (20,)
# longitude_ecmwf:  (240,)

# %%
fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.axes(projection=ccrs.Robinson())
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.set_aspect('auto')
ax.coastlines(linewidth=2)
plt.pcolormesh(lonmesh_ecmwf, latmesh_ecmwf, np.nanmean(V_RMSE[3, :, :, np.isin(V_month,[6,7,8])],0), transform = ccrs.PlateCarree(),cmap='jet')
plt.colorbar(fraction=0.023, pad=0.04, label = 'V_RMSE')
A, B = plt.gci().get_clim()
cmax=np.abs(np.array([A, B])).max()
plt.clim(0, cmax)
plt.show()
